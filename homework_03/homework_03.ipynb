# %% [markdown]
# # Домашнее задание: Функции

# %% [markdown]
# ## Задание 1: Конвертер регистров
#
# Написать функцию, которая будет переводить snake_case в PascalCase и наоборот.
#
# Функция должна сама определять - какой формат ей передали. Можно добавить ключевой аргумент, который будет принудительно возвращать один из форматов.
#
# <br>
#
# **Примеры:**
# * `otus_course     -> OtusCourse`
# * `PythonIsTheBest -> python_is_the_best`

# %%
def ChangeCase(in_str: str ):
    result = ''
    idx = 0
    pos = in_str.find("_")
    camelCaseExist = True
    if pos != -1:
        camelCaseExist = False
    while idx < len(in_str):
        ch =str(in_str[idx])
        if ch.isupper():
            if not camelCaseExist:
                print("snake_case expected but there is ipper case symbol")
                raise ValueError
            else:
                ch = ("_" + ch.lower()) if idx != 0 else ch.lower()
        elif ch == "_":
            idx += 1
            if idx >= len(in_str):
                break
            ch = in_str[idx]
            if not camelCaseExist:
                ch = ch.upper()
            else:
                print("camelCase expected but there is \"_\" symbol")
                raise ValueError
        else:
            if not camelCaseExist and idx == 0:
                ch = ch.upper()
        result += ch
        idx +=1
    return result

in_str = input()

print(ChangeCase(in_str))

# %% [markdown]
# ## Задание 2: Проверка валидности даты
#
# Написать функцию проверяющую валидность введенной даты.
#
# <br>
#
# **Примеры:**
# * `29.02.2000 -> True`
# * `29.02.2001 -> False`
# * `31.04.1962 -> False`

# %%
import datetime
import re

def ParseDateString(in_str: str):
    pattern = r"(\d{2}).(\d{2}).(\d{4})"
    m = re.search(pattern, in_str)
    if not m:
        print("Wrong date format dd.mm.yyyy expected")
        return False
    day = int(m.group(1))
    month = int(m.group(2))
    year = int(m.group(3))
  
    try:
        dt = datetime.datetime(year,month,day)
        return True
    except ValueError:
        print("Wrong date entered.")
        return False


in_str = input()

print(ParseDateString(in_str))

# %% [markdown]
# ## Задание 3: Проверка на простое число
#
# Функция проверки на простое число. Простые числа – это такие числа, которые делятся на себя и на единицу.
#
# <br>
#
# **Примеры:**
# * `17 -> True`
# * `20 -> False`
# * `23 -> True`

# %%
import math

def IsSimple(number: int)->bool:
    if number <=1:
        return False
    if number < 4:
        return True
    
    if (number %2 ==0 or number % 3 == 0):
        return False
    
    idx = 5
    max_diveder = int(math.sqrt(number)) + 1 
    while idx < max_diveder:
        if (number % idx == 0 or number % (idx +2) == 0 ):
            return False
        idx += 6
    return True

number = int(input())
print(IsSimple(number))

# %% [markdown]
# ## Задание 4: Учет пользователей
#
# Пользователь в бесконечном цикле вводит данные пользователей: имя, затем фамилию, возраст и ID. Ввод продолжается до тех пор, пока не будет введено пустое поле.
#
# Пользователи заносятся в словарь, где ключ это ID пользователя, а остальные данные записываются в виде кортежа.
#
# **Программа должна проверять:**
# * имя и фамилия состоят только из символов и начинаются с большой буквы - если не с большой, то заменяет букву на большую;
# * возраст должен быть числом от 18 до 60;
# * ID - целое число, дополненное до 8 знаков незначащими нулями, ID должен быть уникальным.
#
# **Дополнительно:** написать функцию, которая будет выводить полученный словарь в виде таблицы.

# %%
def validate_input(f_name, l_name, age_s, id_s, inout_db):
    
    if not f_name.isalpha():
        print(f"Error: the first name  '{f_name}' should contain only letters.")
        return None
    if not l_name.isalpha():
        print(f"Error: the la '{l_name}' should contain only letters.")
        return None
        
    f_name = f_name.capitalize()
    l_name = l_name.capitalize()

    try:
        age = int(age_s)
    except ValueError:
        print(f"Erorr: Age '{age_s}' should be a numbe.")
        return None
        
    if not (18 <= age <= 60):
        print(f"Erorr: Age {age} should be less than 60 and more than 18.")
        return None

    try:
        user_id = int(id_s)
    except ValueError:
        print(f"Error: ID '{id_s}' should a number.")
        return None
        
    if user_id < 0:
        print("Error: ID '{id_str}' should a positive number.")
        return None
        
    formatted_id = f"{user_id:08d}"
    
    if formatted_id in inout_db:
        print(f"Error {formatted_id} is already exist. It should be unique.")
        return None

    return formatted_id, (f_name, l_name, age)


def print_table(users_dict):
    print("\n" + "=" * 60)
    print(f"{'ID':<10} | {'Имя':<15} | {'Фамилия':<15} | {'Возраст':<8}")
    print("-" * 60)
    
    for user_id, (first_name, last_name, age) in users_dict.items():
        print(f"{user_id:<10} | {first_name:<15} | {last_name:<15} | {age:<8}")
        
    print("=" * 60 + "\n")

users_db={}
print("Please anter user data. LEave empty any filed to finish")

while True:
    first_name = input("Name: ").strip()
    if not first_name: 
        break
    last_name = input("Surnam: ").strip()
    if not last_name: 
        break
    age_str = input("Age: ").strip()
    if not age_str: 
        break
    id_str = input("Enter Id: ").strip()
    if not id_str: 
        break

    result = validate_input(first_name, last_name, age_str, id_str, users_db.keys())
    
    if result:
        formatted_id, user_data = result
        users_db[formatted_id] = user_data
        print(f"-> The user  {user_data[0]} {user_data[1]} was added successfully\n")

print_table(users_db)
# Out:
# Please anter user data. LEave empty any filed to finish
#
# ...
# ID         | Имя             | Фамилия         | Возраст
# ------------------------------------------------------------
# ...
